# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# # This Dataset Contains Dummy data of 5000 Employees of an organization, where names and addresses used are based on random string format 
# beside that all other information is derived and created using specific formulas for calculation like HRA,DA,PF depending on which gross salary 
# is computed. Other organizational parameters like department, Position, Salary Considering Experience and Level, Date of joining and Years of Experience
# \counted based on age considering. maintaining rule like no one joined the company before the age of 21 years along with that years of experience in 
# current organization calculated. some personal factors like marital status, number of dependents, insurance taken or not ?, besides that some other 
# factors have been assured while the creation of dataset like no gender biasness or any other kind of discriminative criteria

# %%
df=pd.read_csv('Dummy_5000_Employee_Details_Dataset.csv')
df.head(50)
# Out:
#     Unnamed: 0      Name                              Address     Salary  \
# 0            0  VgwbPyBn  jyNxKZtk St, piZQhYcARo, PUN 172813  149289.04
# 1            1  pgdYaIWk  PypVsqug St, iHyelKZbFc, BLR 580530   69761.64
# 2            2  eWgVBGVv  pfQezTVa St, YfIaELfpUw, BLR 155186  107633.14
# 3            3  LYDofRRu  wcTsbmFr St, UdylzZFFCU, AMD 843852  147408.65
# 4            4  vhLFHcRg  DdxKVhli St, cYOjpbMztB, BLR 713383   53447.06
# 5            5  mNWPWGPP  vuHIgjXl St, IodaWueNON, PUN 605979  106580.11
# 6            6  vjbszTQW  LLOOZxHr St, iiZXVGMuRa, DEL 672793  146007.75
# 7            7  zXUdTHaJ  XyBINigj St, BxfKiOEuiT, DEL 254142   76986.74
# 8            8  sIZQRTaq  ZrqSMeKj St, BSMxlzAcjl, BLR 743922  134973.46
# 9            9  DTjnhgxd  ZEeBgofu St, BGXeaFhWmT, CHN 978281  120881.83
# 10          10  eBRYbQan  wfXTduBi St, cVZIuyZwoH, PUN 942002  111585.44
# 11          11  eWLUSyxM  mXNzUhRW St, MNtLblAkxo, DEL 748567  110267.59
# 12          12  TNOqMntI  xPZmWZXy St, vbVuwQQynw, KOL 996770  137839.33
# 13          13  YEzLYCDP  dFNERDKi St, jWEHbKUscN, KOL 785625  112335.02
# 14          14  dTYeJIMp  uxCvqweZ St, cjbgwWkfII, MUB 484886   61292.38
# 15          15  WblJTjKQ  zXJyzhSA St, lwDImiwBuY, MUB 832618   54536.79
# 16          16  YoIurhqK  cwoNaCzs St, FahGyBPTBS, HYD 843200  125585.83
# 17          17  OYqIOSgW  ohQMGTOK St, teOUKLFQoc, HYD 193934  110283.78
# 18          18  rsCEIoFW  fEuEweIc St, tVHEqrUgRg, MUB 175099   87870.25
# 19          19  keBeAdyB  yShYbjuQ St, QineuRUlHw, AMD 905299  124569.61
# 20          20  wWrngMod  nqyFJlmb St, xIkJEmrTce, MUB 172623  144338.76
# 21          21  Donbudcg  GziMwnXj St, iKxDKBPWat, PUN 182853  126983.96
# 22          22  cBcpuWQy  rwecAngY St, bFZxVIqYMp, CHN 115558   85553.77
# 23          23  VrwdfHZs  TtquVXrb St, UlCtCDzYeN, KOL 674910   79408.29
# 24          24  DSBBGaaE  PCCoKGZj St, OkxtCRCEpG, PUN 748220   76946.32
# 25          25  dRECiNOs  SPnhEOug St, DwWEIdgGPa, HYD 778707   88732.50
# 26          26  wJmguwBV  llSHbDcL St, KEiTpwFNtA, KOL 530613  126765.30
# 19                  29        Marketing  National Marketing Manager
# 20                  32          Finance       National Account Head
# 21                  31        Marketing  National Marketing Manager
# 22                  12  Human Resources                    ERP Head
# 23                  25          Finance    Senior Account Executive
# 24                  25        Marketing  Regional Marketing Manager
# 25                  20        Marketing  Senior Marketing Executive
# 26                  27        Marketing  National Marketing Manager
# 27                  17  Human Resources                   Senior HR
# 28                  33  Human Resources                 HR Director
# 29                   8            Sales        Sales Representative
# 30                  32  Human Resources                 HR Director
# 31                   2        Marketing            Marketing Intern
# 32                  25               IT                     QA Lead
# 33                  11          Finance       Regional Account Head
# 34                  25          Finance    Senior Account Executive
# 35                   5               IT              QA Engineer II
# 36                  19               IT                     QA Lead
# 37                  13               IT       Software Engineer III
# 38                   9               IT        Software Engineer II
# 39                  39          Finance            Account Director
# 40                   7          Finance           Account Associate
# 41                  29               IT              Technical Lead
# 42                  12  Human Resources                   Senior HR
# 43                  12               IT       Software Engineer III
# 44                   1               IT         Software Engineer I
# 45                  25               IT                     QA Lead
# 46                   3               IT               QA Engineer I
# 47                  17  Human Resources                   Senior HR
# 48                   9  Human Resources                HR Executive
# 49                  34               IT                  IT Manager

# %%
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
df.head()
# Out:
#        Name                              Address     Salary         DOJ  \
# 0  VgwbPyBn  jyNxKZtk St, piZQhYcARo, PUN 172813  149289.04  1998-04-27
# 1  pgdYaIWk  PypVsqug St, iHyelKZbFc, BLR 580530   69761.64  2020-10-24
# 2  eWgVBGVv  pfQezTVa St, YfIaELfpUw, BLR 155186  107633.14  2020-07-22
# 3  LYDofRRu  wcTsbmFr St, UdylzZFFCU, AMD 843852  147408.65  2007-03-27
# 4  vhLFHcRg  DdxKVhli St, cYOjpbMztB, BLR 713383   53447.06  2017-05-23
#
#           DOB  Age     Sex  Dependents        HRA            DA            PF  \
# 0  1971-03-27   53   Other         2.0   8776.096  35233.666375  22142.724765
# 1  1997-12-12   26    Male         0.0   9302.836  16464.425985  10347.127918
# 2  1979-08-20   44  Female         2.0  13357.686  25402.468564  15964.273028
# 3  1966-06-07   58    Male         1.0   6026.135  34789.876034  21863.823124
# 4  1992-11-19   31    Male         2.0   7554.294  12614.026326   7927.330359
#
#     Gross Salary Insurance Marital Status  In Company Years  \
# 0  171156.077610       NaN        Widowed                26
# 1   85181.774067      Both         Single                 3
# 2  130429.021537       NaN       Divorced                 3
# 3  166360.837910       NaN        Married                17
# 4   65688.049967      Life        Married                 7
#
#    Year of Experience       Department                    Position
# 0                  32            Sales              Sales Director
# 1                   5  Human Resources                HR Executive
# 2                  23        Marketing  Senior Marketing Executive
# 3                  37          Finance            Account Director
# 4                  10            Sales             Sales Executive

# %%
def summary(df):
    sum_df = pd.DataFrame(df.dtypes, columns=["dtypes"])
    sum_df["missing"] = df.isna().sum()
    sum_df["missing %"] = (df.isna().sum())/ len(df)
    sum_df["uniques"] = df.nunique().values
    sum_df["count"] = df.count().values
    return sum_df.sort_values("missing %", ascending=False)
summary(df)
# Out:
#                      dtypes  missing  missing %  uniques  count
# Insurance            object     1238     0.2476        3   3762
# Marital Status       object      123     0.0246        4   4877
# Dependents          float64      123     0.0246        5   4877
# Name                 object        0     0.0000     5000   5000
# PF                  float64        0     0.0000     4999   5000
# Department           object        0     0.0000        5   5000
# Year of Experience    int64        0     0.0000       40   5000
# In Company Years      int64        0     0.0000       41   5000
# Gross Salary        float64        0     0.0000     5000   5000
# DA                  float64        0     0.0000     4999   5000
# Address              object        0     0.0000     5000   5000
# HRA                 float64        0     0.0000     5000   5000
# Sex                  object        0     0.0000        3   5000
# Age                   int64        0     0.0000       40   5000
# DOB                  object        0     0.0000     4158   5000
# DOJ                  object        0     0.0000     3721   5000
# Salary              float64        0     0.0000     4999   5000
# Position             object        0     0.0000       40   5000

# %%
import klib
df1=df.copy()
# klib.corr_mat(df)
# klib.corr_plot(df)
# klib.dist_plot(df)
klib.data_cleaning(df1)
# Out:
# Shape of cleaned data: (5000, 18) - Remaining NAs: 1484
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.31 MB (-44.93%)
#           name                              address     salary         doj  \
# 0     VgwbPyBn  jyNxKZtk St, piZQhYcARo, PUN 172813  149289.04  1998-04-27
# 1     pgdYaIWk  PypVsqug St, iHyelKZbFc, BLR 580530   69761.64  2020-10-24
# 2     eWgVBGVv  pfQezTVa St, YfIaELfpUw, BLR 155186  107633.14  2020-07-22
# 3     LYDofRRu  wcTsbmFr St, UdylzZFFCU, AMD 843852  147408.65  2007-03-27
# 4     vhLFHcRg  DdxKVhli St, cYOjpbMztB, BLR 713383   53447.06  2017-05-23
# ...        ...                                  ...        ...         ...
# 4995  qWoLfJfL  ZySbqPyI St, ngMINtRCsM, MUB 927128  129159.11  2015-01-27
# 4996  bSgpJtiF  frtFLglE St, lTFYlKNUjF, HYD 805378  134664.03  2010-08-15
# 4997  gToCBVUH  EYXeRLkj St, VmMSAYuspF, HYD 735138   92852.65  2023-09-18
# 4998  dwTQETtZ  ivLjcIWM St, qWGPFaIuvI, KOL 978537   17412.05  2023-06-02
# 4999  EWrIRxIJ  vVrWcNkW St, NsOMLwTEmX, KOL 378650   91693.80  2021-06-09
#
#              dob  age     sex  dependents           hra            da  \
# 0     1971-03-27   53   Other         2.0   8776.095703  35233.666375
# 1     1997-12-12   26    Male         0.0   9302.835938  16464.425985
# 2     1979-08-20   44  Female         2.0  13357.685547  25402.468564
# 3     1966-06-07   58    Male         1.0   6026.134766  34789.876034
# 4     1992-11-19   31    Male         2.0   7554.293945  12614.026326
# ...          ...  ...     ...         ...           ...           ...
# 4995  1975-02-10   49  Female         2.0   8769.088867  30482.806983
# 4996  1972-12-18   51  Female         3.0  10036.596680  31782.021679
# 4997  1985-09-23   38   Other         4.0   6651.734863  21914.129075
# 4998  2002-07-20   21   Other         0.0   6315.794922   4109.413260
# 4999  1988-01-17   36  Female         3.0   4421.620117  21640.629197
#
#                 pf   gross_salary insurance marital_status  in_company_years  \
# 0     22142.724765  171156.077610       NaN        Widowed                26
# 1     10347.127918   85181.774067      Both         Single                 3
# 2     15964.273028  130429.021537       NaN       Divorced                 3
# 3     21863.823124  166360.837910       NaN        Married                17
# 4      7927.330359   65688.049967      Life        Married                 7
# ...            ...            ...       ...            ...               ...
# 4995  19157.030038  149253.975945   Medical       Divorced                 9
# 4996  19973.526201  156509.122477   Medical       Divorced                13
# 4997  13772.013489  107646.500586   Medical        Married                 0
# 4998   2582.575591   25254.682669      Both         Single                 1
# 4999  13600.131504  104155.917693       NaN        Married                 3
#
#       year_of_experience       department                    position
# 0                     32            Sales              Sales Director
# 1                      5  Human Resources                HR Executive
# 2                     23        Marketing  Senior Marketing Executive
# 3                     37          Finance            Account Director
# 4                     10            Sales             Sales Executive
# ...                  ...              ...                         ...
# 4995                  28               IT                  IT Manager
# 4996                  30            Sales      National Sales Manager
# 4997                  17               IT                     QA Lead
# 4998                   0  Human Resources           HR Representative
# 4999                  15        Marketing  Regional Marketing Manager
#
# [5000 rows x 18 columns]

# %%
# import sweetviz as sv
# my_report=sv.analyze(df1)
# my_report.show_html()

# %%
df1['Dependents'].value_counts()
# Out:
# Dependents
# 2.0    1196
# 1.0    1157
# 3.0     984
# 0.0     786
# 4.0     754
# Name: count, dtype: int64

# %%
df1['Dependents'] = df1['Dependents'].fillna(0.0).astype(int)

# %%
df1['Dependents'].value_counts()
# Out:
# Dependents
# 2    1196
# 1    1157
# 3     984
# 0     909
# 4     754
# Name: count, dtype: int64

# %%
for columns in df1:
    print(f'{columns}:{df1[columns].unique()}')
# Out:
# Name:['VgwbPyBn' 'pgdYaIWk' 'eWgVBGVv' ... 'gToCBVUH' 'dwTQETtZ' 'EWrIRxIJ']
# Address:['jyNxKZtk St, piZQhYcARo, PUN 172813'
#  'PypVsqug St, iHyelKZbFc, BLR 580530'
#  'pfQezTVa St, YfIaELfpUw, BLR 155186' ...
#  'EYXeRLkj St, VmMSAYuspF, HYD 735138'
#  'ivLjcIWM St, qWGPFaIuvI, KOL 978537'
#  'vVrWcNkW St, NsOMLwTEmX, KOL 378650']
# Salary:[149289.04  69761.64 107633.14 ...  92852.65  17412.05  91693.8 ]
# DOJ:['1998-04-27' '2020-10-24' '2020-07-22' ... '2011-02-21' '2019-02-20'
#  '2015-01-27']
# DOB:['1971-03-27' '1997-12-12' '1979-08-20' ... '1975-02-10' '2002-07-20'
#  '1988-01-17']
# Age:[53 26 44 58 31 34 52 32 55 50 48 60 25 56 37 33 46 41 38 54 29 23 40 30
#  28 22 24 51 59 27 36 39 45 57 49 43 42 35 47 21]
# Sex:['Other' 'Male' 'Female']
# Dependents:[2 0 1 3 4]
# HRA:[ 8776.096  9302.836 13357.686 ...  6651.735  6315.795  4421.62 ]
# DA:[35233.6663747  16464.4259854  25402.46856448 ... 21914.12907543
#   4109.41326034 21640.62919708]
# PF:[22142.72476496 10347.12791825 15964.27302774 ... 13772.01348905
#   2582.57559124 13600.13150365]
# Gross Salary:[171156.07760973  85181.77406715 130429.02153674 ... 107646.50058637
#   25254.6826691  104155.91769343]
# Insurance:[nan 'Both' 'Life' 'Medical']
# Marital Status:['Widowed' 'Single' 'Divorced' 'Married' nan]
# In Company Years:[26  3 17  7  1  2  4 18 16 31 24 34 21 13  5 14  9 10 30 19  6 12  8  0
#  15 11 23 27 28 33 25 37 20 -1 36 29 32 22 39 35 38]
# Year of Experience:[32  5 23 37 10 13 31 11 34 29 27 39  4 35 16 12 25 20 17 33  8  2 19  9
#   7  1  3 30 38  6 15 18 24 36 28 22 21 14 26  0]
# Department:['Sales' 'Human Resources' 'Marketing' 'Finance' 'IT']
# Position:['Sales Director' 'HR Executive' 'Senior Marketing Executive'
#  'Account Director' 'Sales Executive' 'Regional Sales Manager'
#  'National Account Head' 'Senior Executive' 'Technical Lead'
#  'National Marketing Manager' 'IT Manager' 'Sales Representative'
#  'Software Engineer II' 'National Sales Manager' 'Senior HR' 'ERP Head'
#  'Senior Account Executive' 'Regional Marketing Manager' 'HR Director'
#  'Marketing Intern' 'QA Lead' 'Regional Account Head' 'QA Engineer II'
#  'Software Engineer III' 'Account Associate' 'Software Engineer I'
#  'QA Engineer I' 'HR Associate' 'Marketing Director' 'Recruitment Manager'
#  'Marketing Representative' 'Accounts Intern' 'Account Representative'
#  'Marketing Associate' 'Account Executive'
#  'Marketing Development Representative' 'HR Intern'
#  'Sales Development Representative' 'HR Representative'
#  'Business Development Representative']

# %%
# Empty list to store columns with categorical data
categorical = []
for col, value in df1.items():
    if value.dtype == 'object':
        categorical.append(col)

# Store the numerical columns in a list numerical
numerical = df1.columns.difference(categorical)

# %%
categorical
# Out:
# ['Name',
#  'Address',
#  'DOJ',
#  'DOB',
#  'Sex',
#  'Insurance',
#  'Marital Status',
#  'Department',
#  'Position']

# %%
numerical
# Out:
# Index(['Age', 'DA', 'Dependents', 'Gross Salary', 'HRA', 'In Company Years',
#        'PF', 'Salary', 'Year of Experience'],
#       dtype='object')

# %%
summary(df1)
# Out:
#                      dtypes  missing  missing %  uniques  count
# Insurance            object     1238     0.2476        3   3762
# Marital Status       object      123     0.0246        4   4877
# Name                 object        0     0.0000     5000   5000
# Address              object        0     0.0000     5000   5000
# Department           object        0     0.0000        5   5000
# Year of Experience    int64        0     0.0000       40   5000
# In Company Years      int64        0     0.0000       41   5000
# Gross Salary        float64        0     0.0000     5000   5000
# PF                  float64        0     0.0000     4999   5000
# DA                  float64        0     0.0000     4999   5000
# HRA                 float64        0     0.0000     5000   5000
# Dependents            int32        0     0.0000        5   5000
# Sex                  object        0     0.0000        3   5000
# Age                   int64        0     0.0000       40   5000
# DOB                  object        0     0.0000     4158   5000
# DOJ                  object        0     0.0000     3721   5000
# Salary              float64        0     0.0000     4999   5000
# Position             object        0     0.0000       40   5000

# %%
df['Insurance'].value_counts()
# Out:
# Insurance
# Both       1292
# Life       1245
# Medical    1225
# Name: count, dtype: int64

# %% [markdown]
# ## Handling missing data

# %%
#Mode
# from sklearn.impute import SimpleImputer
# impute_mode = SimpleImputer(strategy = 'most_frequent')
# impute_mode.fit(df[['Graduated', 'Family_Size']])

# df[['Graduated', 'Family_Size']] = impute_mode.transform(df[['Graduated', 'Family_Size']])


#Imputation by KNN (Nearest Neighbor Approach)

# To perform KNN imputation, we need to normalize the input data and perform One Hot Encoding to categorical variables

# categorical_cols = ['Gender', 'Ever_Married', 'Graduated', 'Profession', 'Spending_Score']
# num_cols = ['Age', 'Work_Experience', 'Family_Size']

# cat_dummies = pd.get_dummies(df_temp[categorical_cols ], drop_first = True)
# df= pd.concat([df[num_cols], cat_dummies], axis = 1)

# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# df = pd.DataFrame(scaler.fit_transform(df), columns = df.columns)

# from sklearn.impute import KNNImputer
# imputer = KNNImputer(n_neighbors = 3)
# df = pd.DataFrame(imputer.fit_transform(df),columns = df.columns)

# Imputation by MICE (Multiple Imputation by Chained Equations)

# %%
df1.shape
# Out:
# (5000, 18)

# %%
df1.rename(columns = {'Marital Status':'Marital_Status','Year of Experience':'YOE','In Company Years':'In_Comp_Yrs'}, inplace = True)

# %%
df1.columns
# Out:
# Index(['Name', 'Address', 'Salary', 'DOJ', 'DOB', 'Age', 'Sex', 'Dependents',
#        'HRA', 'DA', 'PF', 'Gross Salary', 'Insurance', 'Marital_Status',
#        'In_Comp_Yrs', 'YOE', 'Department', 'Position'],
#       dtype='object')

# %%
df2=df1[['Insurance','Marital_Status']]
df2.shape
# Out:
# (5000, 2)

# %%
import numpy as np
import pandas as pd
from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler

mm = MinMaxScaler()


def find_category_mappings(df, variable):
    return {k: i for i, k in enumerate(df[variable].dropna().unique(), 0)}

def integer_encode(df , variable, ordinal_mapping):
    df[variable] = df[variable].map(ordinal_mapping)

mappin = dict()
def imputation(df , cols):
    df = df2.copy()
    #Encoding dict &amp; Removing nan    
    #mappin = dict()
    for variable in cols:
        mappings = find_category_mappings(df, variable)
        mappin[variable] = mappings

    #Apply mapping
    for variable in cols:
        integer_encode(df, variable, mappin[variable])  

    #Minmaxscaler and KNN imputation 
    sca = mm.fit_transform(df)
    knn_imputer = KNNImputer()
    knn = knn_imputer.fit_transform(sca)
    df.iloc[:,:] = mm.inverse_transform(knn)
    for i in df.columns : 
        df[i] = round(df[i]).astype('int')

    #Inverse transform
    for i in cols:
        inv_map = {v: k for k, v in mappin[i].items()}
        df[i] = df[i].map(inv_map)
    return df


#Imputation
# imputation(df,['Insurance','Marital Status'])
df3=imputation(df2,['Insurance','Marital_Status'])

# %%
summary(df3)
# Out:
#                 dtypes  missing  missing %  uniques  count
# Insurance       object        0        0.0        3   5000
# Marital_Status  object        0        0.0        4   5000

# %%
df1[['Insurance','Marital_Status']]=df3[['Insurance','Marital_Status']]

# %%
for columns in df1:
    print(f'{columns}:{df1[columns].unique()}')
# Out:
# Name:['VgwbPyBn' 'pgdYaIWk' 'eWgVBGVv' ... 'gToCBVUH' 'dwTQETtZ' 'EWrIRxIJ']
# Address:['jyNxKZtk St, piZQhYcARo, PUN 172813'
#  'PypVsqug St, iHyelKZbFc, BLR 580530'
#  'pfQezTVa St, YfIaELfpUw, BLR 155186' ...
#  'EYXeRLkj St, VmMSAYuspF, HYD 735138'
#  'ivLjcIWM St, qWGPFaIuvI, KOL 978537'
#  'vVrWcNkW St, NsOMLwTEmX, KOL 378650']
# Salary:[149289.04  69761.64 107633.14 ...  92852.65  17412.05  91693.8 ]
# DOJ:['1998-04-27' '2020-10-24' '2020-07-22' ... '2011-02-21' '2019-02-20'
#  '2015-01-27']
# DOB:['1971-03-27' '1997-12-12' '1979-08-20' ... '1975-02-10' '2002-07-20'
#  '1988-01-17']
# Age:[53 26 44 58 31 34 52 32 55 50 48 60 25 56 37 33 46 41 38 54 29 23 40 30
#  28 22 24 51 59 27 36 39 45 57 49 43 42 35 47 21]
# Sex:['Other' 'Male' 'Female']
# Dependents:[2 0 1 3 4]
# HRA:[ 8776.096  9302.836 13357.686 ...  6651.735  6315.795  4421.62 ]
# DA:[35233.6663747  16464.4259854  25402.46856448 ... 21914.12907543
#   4109.41326034 21640.62919708]
# PF:[22142.72476496 10347.12791825 15964.27302774 ... 13772.01348905
#   2582.57559124 13600.13150365]
# Gross Salary:[171156.07760973  85181.77406715 130429.02153674 ... 107646.50058637
#   25254.6826691  104155.91769343]
# Insurance:['Life' 'Both' 'Medical']
# Marital_Status:['Widowed' 'Single' 'Divorced' 'Married']
# In_Comp_Yrs:[26  3 17  7  1  2  4 18 16 31 24 34 21 13  5 14  9 10 30 19  6 12  8  0
#  15 11 23 27 28 33 25 37 20 -1 36 29 32 22 39 35 38]
# YOE:[32  5 23 37 10 13 31 11 34 29 27 39  4 35 16 12 25 20 17 33  8  2 19  9
#   7  1  3 30 38  6 15 18 24 36 28 22 21 14 26  0]
# Department:['Sales' 'Human Resources' 'Marketing' 'Finance' 'IT']
# Position:['Sales Director' 'HR Executive' 'Senior Marketing Executive'
#  'Account Director' 'Sales Executive' 'Regional Sales Manager'
#  'National Account Head' 'Senior Executive' 'Technical Lead'
#  'National Marketing Manager' 'IT Manager' 'Sales Representative'
#  'Software Engineer II' 'National Sales Manager' 'Senior HR' 'ERP Head'
#  'Senior Account Executive' 'Regional Marketing Manager' 'HR Director'
#  'Marketing Intern' 'QA Lead' 'Regional Account Head' 'QA Engineer II'
#  'Software Engineer III' 'Account Associate' 'Software Engineer I'
#  'QA Engineer I' 'HR Associate' 'Marketing Director' 'Recruitment Manager'
#  'Marketing Representative' 'Accounts Intern' 'Account Representative'
#  'Marketing Associate' 'Account Executive'
#  'Marketing Development Representative' 'HR Intern'
#  'Sales Development Representative' 'HR Representative'
#  'Business Development Representative']

# %%
summary(df1)
# Out:
#                  dtypes  missing  missing %  uniques  count
# Name             object        0        0.0     5000   5000
# Address          object        0        0.0     5000   5000
# Department       object        0        0.0        5   5000
# YOE               int64        0        0.0       40   5000
# In_Comp_Yrs       int64        0        0.0       41   5000
# Marital_Status   object        0        0.0        4   5000
# Insurance        object        0        0.0        3   5000
# Gross Salary    float64        0        0.0     5000   5000
# PF              float64        0        0.0     4999   5000
# DA              float64        0        0.0     4999   5000
# HRA             float64        0        0.0     5000   5000
# Dependents        int32        0        0.0        5   5000
# Sex              object        0        0.0        3   5000
# Age               int64        0        0.0       40   5000
# DOB              object        0        0.0     4158   5000
# DOJ              object        0        0.0     3721   5000
# Salary          float64        0        0.0     4999   5000
# Position         object        0        0.0       40   5000

# %%
df1['State']=df1['Address'].str.rstrip(' ').str.split(' ').str[3]
df1.drop(['Address'], axis=1,inplace=True)

# %%
summary(df1)
# Out:
#                  dtypes  missing  missing %  uniques  count
# Name             object        0        0.0     5000   5000
# Salary          float64        0        0.0     4999   5000
# Position         object        0        0.0       40   5000
# Department       object        0        0.0        5   5000
# YOE               int64        0        0.0       40   5000
# In_Comp_Yrs       int64        0        0.0       41   5000
# Marital_Status   object        0        0.0        4   5000
# Insurance        object        0        0.0        3   5000
# Gross Salary    float64        0        0.0     5000   5000
# PF              float64        0        0.0     4999   5000
# DA              float64        0        0.0     4999   5000
# HRA             float64        0        0.0     5000   5000
# Dependents        int32        0        0.0        5   5000
# Sex              object        0        0.0        3   5000
# Age               int64        0        0.0       40   5000
# DOB              object        0        0.0     4158   5000
# DOJ              object        0        0.0     3721   5000
# State            object        0        0.0        8   5000

# %%
for columns in df1:
    print(f'{columns}:{df1[columns].unique()}')
# Out:
# Name:['VgwbPyBn' 'pgdYaIWk' 'eWgVBGVv' ... 'gToCBVUH' 'dwTQETtZ' 'EWrIRxIJ']
# Salary:[149289.04  69761.64 107633.14 ...  92852.65  17412.05  91693.8 ]
# DOJ:['1998-04-27' '2020-10-24' '2020-07-22' ... '2011-02-21' '2019-02-20'
#  '2015-01-27']
# DOB:['1971-03-27' '1997-12-12' '1979-08-20' ... '1975-02-10' '2002-07-20'
#  '1988-01-17']
# Age:[53 26 44 58 31 34 52 32 55 50 48 60 25 56 37 33 46 41 38 54 29 23 40 30
#  28 22 24 51 59 27 36 39 45 57 49 43 42 35 47 21]
# Sex:['Other' 'Male' 'Female']
# Dependents:[2 0 1 3 4]
# HRA:[ 8776.096  9302.836 13357.686 ...  6651.735  6315.795  4421.62 ]
# DA:[35233.6663747  16464.4259854  25402.46856448 ... 21914.12907543
#   4109.41326034 21640.62919708]
# PF:[22142.72476496 10347.12791825 15964.27302774 ... 13772.01348905
#   2582.57559124 13600.13150365]
# Gross Salary:[171156.07760973  85181.77406715 130429.02153674 ... 107646.50058637
#   25254.6826691  104155.91769343]
# Insurance:['Life' 'Both' 'Medical']
# Marital_Status:['Widowed' 'Single' 'Divorced' 'Married']
# In_Comp_Yrs:[26  3 17  7  1  2  4 18 16 31 24 34 21 13  5 14  9 10 30 19  6 12  8  0
#  15 11 23 27 28 33 25 37 20 -1 36 29 32 22 39 35 38]
# YOE:[32  5 23 37 10 13 31 11 34 29 27 39  4 35 16 12 25 20 17 33  8  2 19  9
#   7  1  3 30 38  6 15 18 24 36 28 22 21 14 26  0]
# Department:['Sales' 'Human Resources' 'Marketing' 'Finance' 'IT']
# Position:['Sales Director' 'HR Executive' 'Senior Marketing Executive'
#  'Account Director' 'Sales Executive' 'Regional Sales Manager'
#  'National Account Head' 'Senior Executive' 'Technical Lead'
#  'National Marketing Manager' 'IT Manager' 'Sales Representative'
#  'Software Engineer II' 'National Sales Manager' 'Senior HR' 'ERP Head'
#  'Senior Account Executive' 'Regional Marketing Manager' 'HR Director'
#  'Marketing Intern' 'QA Lead' 'Regional Account Head' 'QA Engineer II'
#  'Software Engineer III' 'Account Associate' 'Software Engineer I'
#  'QA Engineer I' 'HR Associate' 'Marketing Director' 'Recruitment Manager'
#  'Marketing Representative' 'Accounts Intern' 'Account Representative'
#  'Marketing Associate' 'Account Executive'
#  'Marketing Development Representative' 'HR Intern'
#  'Sales Development Representative' 'HR Representative'
#  'Business Development Representative']
# State:['PUN' 'BLR' 'AMD' 'DEL' 'CHN' 'KOL' 'MUB' 'HYD']

# %%
#No need to do this.But for learning Purpose I did it
df1['DOB'] = pd.to_datetime(df1['DOB'])
df1['YearDOB'] = df1['DOB'].dt.year
df1['MonthDOB'] = df1['DOB'].dt.month
df1['DayDOB'] = df1['DOB'].dt.day
df1['DOJ'] = pd.to_datetime(df1['DOJ'])
df1['YearDOJ'] = df1['DOJ'].dt.year
df1['MonthDOJ'] = df1['DOJ'].dt.month
df1['DayDOJ'] = df1['DOJ'].dt.day

# %%
# df1['In_Comp_Yrs'].replace({-1:0,},inplace=True)

# %%
# df1.drop(['DOB','DOJ','Name','YearDOB','MonthDOB','DayDOB','YearDOJ','MonthDOJ','DayDOJ','Position','Department','YOE','In_Comp_Yrs'], axis=1,inplace=True)
df1.drop(['DOB','DOJ','Name'], axis=1,inplace=True)

# %%
summary(df1)
# Out:
#                  dtypes  missing  missing %  uniques  count
# Salary          float64        0        0.0     4999   5000
# YOE               int64        0        0.0       40   5000
# MonthDOJ          int32        0        0.0       12   5000
# YearDOJ           int32        0        0.0       40   5000
# DayDOB            int32        0        0.0       28   5000
# MonthDOB          int32        0        0.0       12   5000
# YearDOB           int32        0        0.0       39   5000
# State            object        0        0.0        8   5000
# Position         object        0        0.0       40   5000
# Department       object        0        0.0        5   5000
# In_Comp_Yrs       int64        0        0.0       41   5000
# Age               int64        0        0.0       40   5000
# Marital_Status   object        0        0.0        4   5000
# Insurance        object        0        0.0        3   5000
# Gross Salary    float64        0        0.0     5000   5000
# PF              float64        0        0.0     4999   5000
# DA              float64        0        0.0     4999   5000
# HRA             float64        0        0.0     5000   5000
# Dependents        int32        0        0.0        5   5000
# Sex              object        0        0.0        3   5000
# DayDOJ            int32        0        0.0       28   5000

# %%
# Empty list to store columns with categorical data
categorical = []
for col, value in df1.items():
    if value.dtype == 'object':
        categorical.append(col)

# Store the numerical columns in a list numerical
numerical = df1.columns.difference(categorical)

# %%
numerical
# Out:
# Index(['Age', 'DA', 'DayDOB', 'DayDOJ', 'Dependents', 'Gross Salary', 'HRA',
#        'In_Comp_Yrs', 'MonthDOB', 'MonthDOJ', 'PF', 'Salary', 'YOE', 'YearDOB',
#        'YearDOJ'],
#       dtype='object')

# %%
categorical
# Out:
# ['Sex', 'Insurance', 'Marital_Status', 'Department', 'Position', 'State']

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
for column in categorical:
    df1[column] = labelencoder.fit_transform(df1[column])

# %%
summary(df1)
# Out:
#                  dtypes  missing  missing %  uniques  count
# Salary          float64        0        0.0     4999   5000
# YOE               int64        0        0.0       40   5000
# MonthDOJ          int32        0        0.0       12   5000
# YearDOJ           int32        0        0.0       40   5000
# DayDOB            int32        0        0.0       28   5000
# MonthDOB          int32        0        0.0       12   5000
# YearDOB           int32        0        0.0       39   5000
# State             int32        0        0.0        8   5000
# Position          int32        0        0.0       40   5000
# Department        int32        0        0.0        5   5000
# In_Comp_Yrs       int64        0        0.0       41   5000
# Age               int64        0        0.0       40   5000
# Marital_Status    int32        0        0.0        4   5000
# Insurance         int32        0        0.0        3   5000
# Gross Salary    float64        0        0.0     5000   5000
# PF              float64        0        0.0     4999   5000
# DA              float64        0        0.0     4999   5000
# HRA             float64        0        0.0     5000   5000
# Dependents        int32        0        0.0        5   5000
# Sex               int32        0        0.0        3   5000
# DayDOJ            int32        0        0.0       28   5000

# %%
df1.head()
# Out:
#       Salary  Age  Sex  Dependents        HRA            DA            PF  \
# 0  149289.04   53    2           2   8776.096  35233.666375  22142.724765
# 1   69761.64   26    1           0   9302.836  16464.425985  10347.127918
# 2  107633.14   44    0           2  13357.686  25402.468564  15964.273028
# 3  147408.65   58    1           1   6026.135  34789.876034  21863.823124
# 4   53447.06   31    1           2   7554.294  12614.026326   7927.330359
#
#     Gross Salary  Insurance  Marital_Status  ...  YOE  Department  Position  \
# 0  171156.077610          1               3  ...   32           4        29
# 1   85181.774067          0               2  ...    5           1         9
# 2  130429.021537          1               0  ...   23           3        35
# 3  166360.837910          1               1  ...   37           0         1
# 4   65688.049967          1               1  ...   10           4        30
#
#    State  YearDOB  MonthDOB  DayDOB  YearDOJ  MonthDOJ  DayDOJ
# 0      7     1971         3      27     1998         4      27
# 1      1     1997        12      12     2020        10      24
# 2      1     1979         8      20     2020         7      22
# 3      0     1966         6       7     2007         3      27
# 4      1     1992        11      19     2017         5      23
#
# [5 rows x 21 columns]

# %%
import klib
klib.corr_mat(df1)
# Out:
# C:\Users\varkumar\AppData\Local\anaconda3\Lib\site-packages\klib\describe.py:275: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   return corr.style.applymap(color_negative_red).format("{:.2f}", na_rep="-")
# <style type="text/css">
# #T_06e08_row0_col0, #T_06e08_row0_col1, #T_06e08_row0_col3, #T_06e08_row0_col4, #T_06e08_row0_col5, #T_06e08_row0_col6, #T_06e08_row0_col7, #T_06e08_row0_col8, #T_06e08_row0_col10, #T_06e08_row0_col11, #T_06e08_row0_col12, #T_06e08_row0_col13, #T_06e08_row0_col14, #T_06e08_row0_col20, #T_06e08_row1_col0, #T_06e08_row1_col1, #T_06e08_row1_col3, #T_06e08_row1_col4, #T_06e08_row1_col5, #T_06e08_row1_col6, #T_06e08_row1_col7, #T_06e08_row1_col8, #T_06e08_row1_col10, #T_06e08_row1_col11, #T_06e08_row1_col12, #T_06e08_row1_col13, #T_06e08_row1_col14, #T_06e08_row1_col19, #T_06e08_row1_col20, #T_06e08_row2_col2, #T_06e08_row2_col3, #T_06e08_row2_col9, #T_06e08_row2_col10, #T_06e08_row2_col12, #T_06e08_row2_col14, #T_06e08_row2_col15, #T_06e08_row2_col20, #T_06e08_row3_col0, #T_06e08_row3_col1, #T_06e08_row3_col2, #T_06e08_row3_col3, #T_06e08_row3_col4, #T_06e08_row3_col5, #T_06e08_row3_col6, #T_06e08_row3_col7, #T_06e08_row3_col8, #T_06e08_row3_col10, #T_06e08_row3_col11, #T_06e08_row3_col12, #T_06e08_row3_col13, #T_06e08_row3_col17, #T_06e08_row4_col0, #T_06e08_row4_col1, #T_06e08_row4_col3, #T_06e08_row4_col4, #T_06e08_row4_col5, #T_06e08_row4_col6, #T_06e08_row4_col7, #T_06e08_row4_col8, #T_06e08_row4_col10, #T_06e08_row4_col11, #T_06e08_row4_col12, #T_06e08_row4_col13, #T_06e08_row4_col17, #T_06e08_row4_col20, #T_06e08_row5_col0, #T_06e08_row5_col1, #T_06e08_row5_col3, #T_06e08_row5_col4, #T_06e08_row5_col5, #T_06e08_row5_col6, #T_06e08_row5_col7, #T_06e08_row5_col8, #T_06e08_row5_col10, #T_06e08_row5_col11, #T_06e08_row5_col12, #T_06e08_row5_col13, #T_06e08_row5_col14, #T_06e08_row5_col20, #T_06e08_row6_col0, #T_06e08_row6_col1, #T_06e08_row6_col3, #T_06e08_row6_col4, #T_06e08_row6_col5, #T_06e08_row6_col6, #T_06e08_row6_col7, #T_06e08_row6_col8, #T_06e08_row6_col10, #T_06e08_row6_col11, #T_06e08_row6_col12, #T_06e08_row6_col13, #T_06e08_row6_col14, #T_06e08_row6_col20, #T_06e08_row7_col0, #T_06e08_row7_col1, #T_06e08_row7_col3, #T_06e08_row7_col4, #T_06e08_row7_col5, #T_06e08_row7_col6, #T_06e08_row7_col7, #T_06e08_row7_col8, #T_06e08_row7_col10, #T_06e08_row7_col11, #T_06e08_row7_col12, #T_06e08_row7_col13, #T_06e08_row7_col14, #T_06e08_row7_col20, #T_06e08_row8_col0, #T_06e08_row8_col1, #T_06e08_row8_col3, #T_06e08_row8_col4, #T_06e08_row8_col5, #T_06e08_row8_col6, #T_06e08_row8_col7, #T_06e08_row8_col8, #T_06e08_row8_col10, #T_06e08_row8_col11, #T_06e08_row8_col12, #T_06e08_row8_col13, #T_06e08_row8_col16, #T_06e08_row8_col17, #T_06e08_row8_col20, #T_06e08_row9_col2, #T_06e08_row9_col9, #T_06e08_row9_col14, #T_06e08_row9_col15, #T_06e08_row9_col16, #T_06e08_row9_col17, #T_06e08_row9_col18, #T_06e08_row10_col0, #T_06e08_row10_col1, #T_06e08_row10_col2, #T_06e08_row10_col3, #T_06e08_row10_col4, #T_06e08_row10_col5, #T_06e08_row10_col6, #T_06e08_row10_col7, #T_06e08_row10_col8, #T_06e08_row10_col10, #T_06e08_row10_col11, #T_06e08_row10_col12, #T_06e08_row10_col13, #T_06e08_row10_col16, #T_06e08_row10_col17, #T_06e08_row10_col20, #T_06e08_row11_col0, #T_06e08_row11_col1, #T_06e08_row11_col3, #T_06e08_row11_col4, #T_06e08_row11_col5, #T_06e08_row11_col6, #T_06e08_row11_col7, #T_06e08_row11_col8, #T_06e08_row11_col10, #T_06e08_row11_col11, #T_06e08_row11_col12, #T_06e08_row11_col13, #T_06e08_row11_col14, #T_06e08_row11_col19, #T_06e08_row11_col20, #T_06e08_row12_col0, #T_06e08_row12_col1, #T_06e08_row12_col2, #T_06e08_row12_col3, #T_06e08_row12_col4, #T_06e08_row12_col5, #T_06e08_row12_col6, #T_06e08_row12_col7, #T_06e08_row12_col8, #T_06e08_row12_col10, #T_06e08_row12_col11, #T_06e08_row12_col12, #T_06e08_row12_col13, #T_06e08_row12_col16, #T_06e08_row12_col19, #T_06e08_row12_col20, #T_06e08_row13_col0, #T_06e08_row13_col1, #T_06e08_row13_col3, #T_06e08_row13_col4, #T_06e08_row13_col5, #T_06e08_row13_col6, #T_06e08_row13_col7, #T_06e08_row13_col8, #T_06e08_row13_col10, #T_06e08_row13_col11, #T_06e08_row13_col12, #T_06e08_row13_col13, #T_06e08_row13_col14, #T_06e08_row13_col16, #T_06e08_row13_col19, #T_06e08_row13_col20, #T_06e08_ ...
#   color: None;
# }
# #T_06e08_row0_col2, #T_06e08_row0_col9, #T_06e08_row0_col15, #T_06e08_row0_col16, #T_06e08_row0_col17, #T_06e08_row0_col18, #T_06e08_row0_col19, #T_06e08_row1_col2, #T_06e08_row1_col9, #T_06e08_row1_col15, #T_06e08_row1_col16, #T_06e08_row1_col17, #T_06e08_row1_col18, #T_06e08_row2_col0, #T_06e08_row2_col1, #T_06e08_row2_col4, #T_06e08_row2_col5, #T_06e08_row2_col6, #T_06e08_row2_col7, #T_06e08_row2_col8, #T_06e08_row2_col11, #T_06e08_row2_col13, #T_06e08_row2_col16, #T_06e08_row2_col17, #T_06e08_row2_col18, #T_06e08_row2_col19, #T_06e08_row3_col9, #T_06e08_row3_col14, #T_06e08_row3_col15, #T_06e08_row3_col16, #T_06e08_row3_col18, #T_06e08_row3_col19, #T_06e08_row3_col20, #T_06e08_row4_col2, #T_06e08_row4_col9, #T_06e08_row4_col14, #T_06e08_row4_col15, #T_06e08_row4_col16, #T_06e08_row4_col18, #T_06e08_row4_col19, #T_06e08_row5_col2, #T_06e08_row5_col9, #T_06e08_row5_col15, #T_06e08_row5_col16, #T_06e08_row5_col17, #T_06e08_row5_col18, #T_06e08_row5_col19, #T_06e08_row6_col2, #T_06e08_row6_col9, #T_06e08_row6_col15, #T_06e08_row6_col16, #T_06e08_row6_col17, #T_06e08_row6_col18, #T_06e08_row6_col19, #T_06e08_row7_col2, #T_06e08_row7_col9, #T_06e08_row7_col15, #T_06e08_row7_col16, #T_06e08_row7_col17, #T_06e08_row7_col18, #T_06e08_row7_col19, #T_06e08_row8_col2, #T_06e08_row8_col9, #T_06e08_row8_col14, #T_06e08_row8_col15, #T_06e08_row8_col18, #T_06e08_row8_col19, #T_06e08_row9_col0, #T_06e08_row9_col1, #T_06e08_row9_col3, #T_06e08_row9_col4, #T_06e08_row9_col5, #T_06e08_row9_col6, #T_06e08_row9_col7, #T_06e08_row9_col8, #T_06e08_row9_col10, #T_06e08_row9_col11, #T_06e08_row9_col12, #T_06e08_row9_col13, #T_06e08_row9_col19, #T_06e08_row9_col20, #T_06e08_row10_col9, #T_06e08_row10_col14, #T_06e08_row10_col15, #T_06e08_row10_col18, #T_06e08_row10_col19, #T_06e08_row11_col2, #T_06e08_row11_col9, #T_06e08_row11_col15, #T_06e08_row11_col16, #T_06e08_row11_col17, #T_06e08_row11_col18, #T_06e08_row12_col9, #T_06e08_row12_col14, #T_06e08_row12_col15, #T_06e08_row12_col17, #T_06e08_row12_col18, #T_06e08_row13_col2, #T_06e08_row13_col9, #T_06e08_row13_col15, #T_06e08_row13_col17, #T_06e08_row13_col18, #T_06e08_row14_col3, #T_06e08_row14_col4, #T_06e08_row14_col8, #T_06e08_row14_col10, #T_06e08_row14_col12, #T_06e08_row14_col15, #T_06e08_row14_col16, #T_06e08_row14_col20, #T_06e08_row15_col0, #T_06e08_row15_col1, #T_06e08_row15_col3, #T_06e08_row15_col4, #T_06e08_row15_col5, #T_06e08_row15_col6, #T_06e08_row15_col7, #T_06e08_row15_col8, #T_06e08_row15_col10, #T_06e08_row15_col11, #T_06e08_row15_col12, #T_06e08_row15_col13, #T_06e08_row15_col14, #T_06e08_row15_col17, #T_06e

# %%
df1.drop(['YearDOB','MonthDOB','DayDOB','YearDOJ','MonthDOJ','DayDOJ'], axis=1,inplace=True)

# %%
klib.corr_mat(df1)
# Out:
# C:\Users\varkumar\AppData\Local\anaconda3\Lib\site-packages\klib\describe.py:275: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   return corr.style.applymap(color_negative_red).format("{:.2f}", na_rep="-")
# <style type="text/css">
# #T_1bd36_row0_col0, #T_1bd36_row0_col1, #T_1bd36_row0_col3, #T_1bd36_row0_col4, #T_1bd36_row0_col5, #T_1bd36_row0_col6, #T_1bd36_row0_col7, #T_1bd36_row0_col8, #T_1bd36_row0_col10, #T_1bd36_row0_col11, #T_1bd36_row0_col12, #T_1bd36_row0_col13, #T_1bd36_row0_col14, #T_1bd36_row1_col0, #T_1bd36_row1_col1, #T_1bd36_row1_col3, #T_1bd36_row1_col4, #T_1bd36_row1_col5, #T_1bd36_row1_col6, #T_1bd36_row1_col7, #T_1bd36_row1_col8, #T_1bd36_row1_col10, #T_1bd36_row1_col11, #T_1bd36_row1_col12, #T_1bd36_row1_col13, #T_1bd36_row1_col14, #T_1bd36_row2_col2, #T_1bd36_row2_col3, #T_1bd36_row2_col9, #T_1bd36_row2_col10, #T_1bd36_row2_col12, #T_1bd36_row2_col14, #T_1bd36_row3_col0, #T_1bd36_row3_col1, #T_1bd36_row3_col2, #T_1bd36_row3_col3, #T_1bd36_row3_col4, #T_1bd36_row3_col5, #T_1bd36_row3_col6, #T_1bd36_row3_col7, #T_1bd36_row3_col8, #T_1bd36_row3_col10, #T_1bd36_row3_col11, #T_1bd36_row3_col12, #T_1bd36_row3_col13, #T_1bd36_row4_col0, #T_1bd36_row4_col1, #T_1bd36_row4_col3, #T_1bd36_row4_col4, #T_1bd36_row4_col5, #T_1bd36_row4_col6, #T_1bd36_row4_col7, #T_1bd36_row4_col8, #T_1bd36_row4_col10, #T_1bd36_row4_col11, #T_1bd36_row4_col12, #T_1bd36_row4_col13, #T_1bd36_row5_col0, #T_1bd36_row5_col1, #T_1bd36_row5_col3, #T_1bd36_row5_col4, #T_1bd36_row5_col5, #T_1bd36_row5_col6, #T_1bd36_row5_col7, #T_1bd36_row5_col8, #T_1bd36_row5_col10, #T_1bd36_row5_col11, #T_1bd36_row5_col12, #T_1bd36_row5_col13, #T_1bd36_row5_col14, #T_1bd36_row6_col0, #T_1bd36_row6_col1, #T_1bd36_row6_col3, #T_1bd36_row6_col4, #T_1bd36_row6_col5, #T_1bd36_row6_col6, #T_1bd36_row6_col7, #T_1bd36_row6_col8, #T_1bd36_row6_col10, #T_1bd36_row6_col11, #T_1bd36_row6_col12, #T_1bd36_row6_col13,
T_1bd36_row5_col9, #T_1bd36_row6_col2, #T_1bd36_row6_col9, #T_1bd36_row7_col2, #T_1bd36_row7_col9, #T_1bd36_row8_col2, #T_1bd36_row8_col9, #T_1bd36_row8_col14, #T_1bd36_row9_col0, #T_1bd36_row9_col1, #T_1bd36_row9_col3, #T_1bd36_row9_col4, #T_1bd36_row9_col5, #T_1bd36_row9_col6, #T_1bd36_row9_col7, #T_1bd36_row9_col8, #T_1bd36_row9_col10, #T_1bd36_row9_col11, #T_1bd36_row9_col12, #T_1bd36_row9_col13, #T_1bd36_row10_col9, #T_1bd36_row10_col14, #T_1bd36_row11_col2, #T_1bd36_row11_col9, #T_1bd36_row12_col9, #T_1bd36_row12_col14, #T_1bd36_row13_col2, #T_1bd36_row13_col9, #T_1bd36_row14_col3, #T_1bd36_row14_col4, #T_1bd36_row14_col8, #T_1bd36_row14_col10, #T_1bd36_row14_col12 {
#   color: #FF3344;
# }
# </style>
# <table id="T_1bd36">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1bd36_level0_col0" class="col_heading level0 col0" >Salary</th>
#       <th id="T_1bd36_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_1bd36_level0_col2" class="col_heading level0 col2" >Sex</th>
#       <th id="T_1bd36_level0_col3" class="col_heading level0 col3" >Dependents</th>
#       <th id="T_1bd36_level0_col4" class="col_heading level0 col4" >HRA</th>
#       <th id="T_1bd36_level0_col5" class="col_heading level0 col5" >DA</th>
#       <th id="T_1bd36_level0_col6" class="col_heading level0 col6" >PF</th>
#       <th id="T_1bd36_level0_col7" class="col_heading level0 col7" >Gross Salary</th>
#       <th id="T_1bd36_level0_col8" class="col_heading level0 col8" >Insurance</th>
#       <th id="T_1bd36_level0_col9" class="col_heading level0 col9" >Marital_Status</th>
#       <th id="T_1bd36_level0_col10" class="col_heading level0 col10" >In_Comp_Yrs</th>
#       <th id="T_1bd36_level0_col11" class="col_heading level0 col11" >YOE</th>
#       <th id="T_1bd36_level0_col12" class="col_heading level0 col12" >Department</th>
#       <th id="T_1bd36_level0_col13" class="col_heading level0 col13" >Position</th>
#       <th id="T_1bd36_level0_col14" class="col_heading level0 col14" >State</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bd36_level0_row0" class="row_heading level0 row0" >Salary</th>
#       <td id="T_1bd36_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_1bd36_row0_col1" class="data row0 col1" >0.90</td>
#       <td id="T_1bd36_row0_col2" class="data row0 col2" >-0.02</td>
#       <td id="T_1bd36_row0_col3" class="data row0 col3" >0.36</td>
#       <td id="T_1bd36_row0_col4" class="data row0 col4" >0.21</td>
#       <td id="T_1bd36_row0_col5" class="data row0 col5" >1.00</td>
#       <td id="T_1bd36_row0_col6" class="data row0 col6" >1.00</td>
#       <td id="T_1bd36_row0_col7" class="data row0 col7" >1.00</td>
#       <td id="T_1bd36_row0_col8" class="data row0 col8" >0.02</td>
#       <td id="T_1bd36_row0_col9" class="data row0 col9" >-0.18</td>
#       <td id="T_1bd36_row0_col10" class="data row0 col10" >0.58</td>
#       <td id="T_1bd36_row0_col11" class="data row0 col11" >0.90</td>
#       <td id="T_1bd36_row0_col12" class="data row0 col12" >0.03</td>
#       <td id="T_1bd36_row0_col13" class="data row0 col13" >0.09</td>
#       <td id="T_1bd36_row0_col14" class="data row0 col14" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_1bd36_level0_row1" class="row_heading level0 row1" >Age</th>
#       <td id="T_1bd36_row1_col0" class="data row1 col0" >0.90</td>
#       <td id="T_1bd36_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_1bd36_row1_col2" class="data row1 col2" >-0.01</td>
#       <td id="T_1bd36_row1_col3" class="data row1 col3" >0.31</td>
#       <td id="T_1bd36_row1_col4" class="data row1 col4" >0.20</td>
#       <td id="T_1bd36_row1_col5" class="data row1 col5" >0.90</td>
#       <td id="T_1bd36_row1_col6" class="data row1 col6" >0.90</td>
#       <td id="T_1bd36_row1_col7" class="data row1 col7" >0.90</td>
#       <td id="T_1bd36_row1_col8" class="data row1 col8" >0.01</td>
#       <td id="T_1bd36_row1_col9" class="data row1 col9" >-0.15</td>
#       <td id="T_1bd36_row1_col10" class="data row1 col10" >0.66</td>

# %%
klib.dist_plot(df1)
# Out:
# <Axes: xlabel='State', ylabel='Density'>

# %%
# #scatterplot
# plt.figure(figsize=(18,6))
# plt.grid()
# plt.scatter(df1['Salary'],df1['Gross Salary'],c='k',marker='x')
# plt.xlabel('Salary')
# plt.ylabel('Gross Salary')
# plt.show()

# %%
# cols= df1.columns.difference(['Gross Salary'])

# %%
columns = ['Salary', 'PF','In_Comp_Yrs','HRA','DA']
filter_ = (df1[columns] > 0).all(axis=1)
df2=df1[filter_]

# %%
df2.head()
# Out:
#       Salary  Age  Sex  Dependents        HRA            DA            PF  \
# 0  149289.04   53    2           2   8776.096  35233.666375  22142.724765
# 1   69761.64   26    1           0   9302.836  16464.425985  10347.127918
# 2  107633.14   44    0           2  13357.686  25402.468564  15964.273028
# 3  147408.65   58    1           1   6026.135  34789.876034  21863.823124
# 4   53447.06   31    1           2   7554.294  12614.026326   7927.330359
#
#     Gross Salary  Insurance  Marital_Status  In_Comp_Yrs  YOE  Department  \
# 0  171156.077610          1               3           26   32           4
# 1   85181.774067          0               2            3    5           1
# 2  130429.021537          1               0            3   23           3
# 3  166360.837910          1               1           17   37           0
# 4   65688.049967          1               1            7   10           4
#
#    Position  State
# 0        29      7
# 1         9      1
# 2        35      1
# 3         1      0
# 4        30      1

# %%
df2.shape
# Out:
# (4575, 15)

# %%
import sweetviz as sv
my_report=sv.analyze(df2)
my_report.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
df3=df2.drop(['HRA','PF','DA'], axis=1,inplace=False)

# %%
# the independent variables set
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calculate_VIF(df):
    df3=df
    vif2_data = pd.DataFrame()
    vif2_data["Feature"] = df3.columns
    # calculating VIF for each feature
    vif2_data["VIF"] = [variance_inflation_factor(df3.values, i)
                          for i in range(len(df3.columns))]
    return vif2_data  
# print(vif2_data)

# %%
calculate_VIF(df3)
# Out:
#            Feature         VIF
# 0           Salary  240.453041
# 1              Age  147.835073
# 2              Sex    1.001688
# 3       Dependents    1.191505
# 4     Gross Salary  237.656920
# 5        Insurance    1.002889
# 6   Marital_Status    1.117611
# 7      In_Comp_Yrs    1.724341
# 8              YOE   49.864505
# 9       Department    1.185935
# 10        Position    1.232605
# 11           State    1.004134

# %%
df4=df3.drop(['Gross Salary'], axis=1,inplace=False)

# %%
calculate_VIF(df4)
# Out:
#            Feature         VIF
# 0           Salary    4.872271
# 1              Age  111.661805
# 2              Sex    1.001684
# 3       Dependents    1.191461
# 4        Insurance    1.002726
# 5   Marital_Status    1.117533
# 6      In_Comp_Yrs    1.723517
# 7              YOE   39.612888
# 8       Department    1.185928
# 9         Position    1.231866
# 10           State    1.003180

# %%
df4.drop(['Age','YOE'], axis=1,inplace=True)

# %%
calculate_VIF(df4)
# Out:
#           Feature        VIF
# 0          Salary  11.815436
# 1             Sex   2.342182
# 2      Dependents   3.792732
# 3       Insurance   2.728079
# 4  Marital_Status   2.629708
# 5     In_Comp_Yrs   3.692913
# 6      Department   3.501056
# 7        Position   5.122473
# 8           State   3.050705

# %%
from sklearn.model_selection import train_test_split

X = df4.drop(['Insurance'], axis=1)
y = df4['Insurance']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.1)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

def find_best_model_using_gridsearchcv(X,y):
    algos = {
        'logistic_regression' : {
            'model': LogisticRegression(),
            'params': {
               'logisticregression__penalty' : ['l2'],
                'logisticregression__multi_class' : ['auto', 'ovr', 'multinomial'],
                'logisticregression__fit_intercept' : [True, False],
                 'logisticregression__n_jobs' : [1,2,3],
                'logisticregression__solver':['lbfgs'], 
                'logisticregression__max_iter':[400]
            }
        },
         'KNN': {
             'model': KNeighborsClassifier(),
             'params': {
                 'kneighborsclassifier__weights': ['uniform', 'distance'],
                 'kneighborsclassifier__algorithm': ['ball_tree', 'kd_tree']
             }
        },
        'SVC': {
             'model': SVC(),
             'params': {
                 'svc__shrinking' : [True, False],
                 # 'splitter': ['best','random'],
                 'svc__decision_function_shape' : ['ovo', 'ovr']
             }
        },
         'GaussianNB': {
             'model':GaussianNB(),
             'params': {
                
         }         
        },
         'Decision_tree_classifier': {
             'model':DecisionTreeClassifier(),
             'params': {
                 'decisiontreeclassifier__criterion':['gini','entropy'],
                 'decisiontreeclassifier__max_features':['sqrt','log2']
                
         }         
        },
         'RandomForestClassifier': {
             'model':RandomForestClassifier(),
             'params': {
                 'randomforestclassifier__n_estimators':[1000]
                 
                
         }         
        }
        
    }
     
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    # # define the pipeline
    # trans=scale
  
    for algo_name, config in algos.items():
        pipe = make_pipeline(StandardScaler(), config['model'])
        gs =  GridSearchCV(pipe, config['params'], cv=5, error_score='raise',return_train_score=False)
       # gs =  GridSearchCV(pipeline,config['params'], cv=cv, error_score='raise',return_train_score=False)

        # gs =  make_pipeline(StandardScaler(),
        # GridSearchCV(config['model'], config['params'], cv=cv, error_score='raise',return_train_score=False)
        #                    )
        gs.fit(X,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])
# trans = MinMaxScaler()
# trans=StandardScaler()
find_best_model_using_gridsearchcv(X,y)
# Out:
#                       model  best_score  \
# 0       logistic_regression    0.498579
# 1                       KNN    0.404590
# 2                       SVC    0.498798
# 3                GaussianNB    0.498579
# 4  Decision_tree_classifier    0.380765
# 5    RandomForestClassifier    0.442842
#
#                                          best_params
# 0  {'logisticregression__fit_intercept': True, 'l...
# 1  {'kneighborsclassifier__algorithm': 'ball_tree...
# 2  {'svc__decision_function_shape': 'ovo', 'svc__...
# 3                                                 {}
# 4  {'decisiontreeclassifier__criterion': 'entropy...
# 5     {'randomforestclassifier__n_estimators': 1000}
