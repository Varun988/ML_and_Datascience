# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
# import osimport graphviz
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_curve, auc, roc_curve

# %%
df=pd.read_csv('mushrooms.csv')
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
def summary(df):
    sum_df = pd.DataFrame(df.dtypes, columns=["dtypes"])
    sum_df["missing"] = df.isna().sum()
    sum_df["missing %"] = (df.isna().sum())/ len(df)
    sum_df["uniques"] = df.nunique().values
    sum_df["count"] = df.count().values
    return sum_df.sort_values("missing %", ascending=False)
summary(df)
# Out:
#                           dtypes  missing  missing %  uniques  count
# class                     object        0        0.0        2   8124
# stalk-surface-above-ring  object        0        0.0        4   8124
# population                object        0        0.0        6   8124
# spore-print-color         object        0        0.0        9   8124
# ring-type                 object        0        0.0        5   8124
# ring-number               object        0        0.0        3   8124
# veil-color                object        0        0.0        4   8124
# veil-type                 object        0        0.0        1   8124
# stalk-color-below-ring    object        0        0.0        9   8124
# stalk-color-above-ring    object        0        0.0        9   8124
# stalk-surface-below-ring  object        0        0.0        4   8124
# stalk-root                object        0        0.0        5   8124
# cap-shape                 object        0        0.0        6   8124
# stalk-shape               object        0        0.0        2   8124
# gill-color                object        0        0.0       12   8124
# gill-size                 object        0        0.0        2   8124
# gill-spacing              object        0        0.0        2   8124
# gill-attachment           object        0        0.0        2   8124
# odor                      object        0        0.0        9   8124
# bruises                   object        0        0.0        2   8124
# cap-color                 object        0        0.0       10   8124
# cap-surface               object        0        0.0        4   8124
# habitat                   object        0        0.0        7   8124

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
df['class'].value_counts()
# Out:
# class
# e    4208
# p    3916
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# top                         w                      w         p          w
# freq                     4464                   4384      8124       7924
#
#        ring-number ring-type spore-print-color population habitat
# count         8124      8124              8124       8124    8124
# unique           3         5                 9          6       7
# top              o         p                 w          v       d
# freq          7488      3968              2388       4040    3148
#
# [4 rows x 23 columns]

# %% [raw]
# The data is categorical so we'll use LabelEncoder to convert it to ordinal. LabelEncoder converts each value in a column to a number.
#
# This approach requires the category column to be of 'category' datatype. By default, a non-numerical column is of 'object' datatype. From the df.describe() method, we saw that our columns are of 'object' datatype. So we will have to change the type to 'category' before using this approach.

# %%
df.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %%
import sweetviz as sv
my_report=sv.analyze(df)
my_report.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
df = df.astype('category')
df.dtypes
# Out:
# class                       category
# cap-shape                   category
# cap-surface                 category
# cap-color                   category
# bruises                     category
# odor                        category
# gill-attachment             category
# gill-spacing                category
# gill-size                   category
# gill-color                  category
# stalk-shape                 category
# stalk-root                  category
# stalk-surface-above-ring    category
# stalk-surface-below-ring    category
# stalk-color-above-ring      category
# stalk-color-below-ring      category
# veil-type                   category
# veil-color                  category
# ring-number                 category
# ring-type                   category
# spore-print-color           category
# population                  category
# habitat                     category
# dtype: object

# %%
labelencoder=LabelEncoder()
for column in df.columns:
    df[column] = labelencoder.fit_transform(df[column])

# %%
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       7                       7          0           2
# 1                       7                       7          0           2
# 2                       7                       7          0           2
# 3                       7                       7          0           2
# 4                       7                       7          0           2
#
#    ring-number  ring-type  spore-print-color  population  habitat
# 0            1          4                  2           3        5
# 1            1          4                  3           2        1
# 2            1          4                  3           2        3
# 3            1          4                  2           3        5
# 4            1          0                  3           0        1
#
# [5 rows x 23 columns]

# %%
def summary(df):
    sum_df = pd.DataFrame(df.dtypes, columns=["dtypes"])
    sum_df["missing"] = df.isna().sum()
    sum_df["missing %"] = (df.isna().sum())/ len(df)
    sum_df["uniques"] = df.nunique().values
    sum_df["count"] = df.count().values
    return sum_df.sort_values("missing %", ascending=False)
summary(df)
# Out:
#                          dtypes  missing  missing %  uniques  count
# class                     int32        0        0.0        2   8124
# stalk-surface-above-ring  int32        0        0.0        4   8124
# population                int32        0        0.0        6   8124
# spore-print-color         int32        0        0.0        9   8124
# ring-type                 int32        0        0.0        5   8124
# ring-number               int32        0        0.0        3   8124
# veil-color                int32        0        0.0        4   8124
# veil-type                 int32        0        0.0        1   8124
# stalk-color-below-ring    int32        0        0.0        9   8124
# stalk-color-above-ring    int32        0        0.0        9   8124
# stalk-surface-below-ring  int32        0        0.0        4   8124
# stalk-root                int32        0        0.0        5   8124
# cap-shape                 int32        0        0.0        6   8124
# stalk-shape               int32        0        0.0        2   8124
# gill-color                int32        0        0.0       12   8124
# gill-size                 int32        0        0.0        2   8124
# gill-spacing              int32        0        0.0        2   8124
# gill-attachment           int32        0        0.0        2   8124
# odor                      int32        0        0.0        9   8124
# bruises                   int32        0        0.0        2   8124
# cap-color                 int32        0        0.0       10   8124
# cap-surface               int32        0        0.0        4   8124
# habitat                   int32        0        0.0        7   8124

# %% [raw]
# the column 'veil-type' is 0 and not contributing to the data so we'll remove it

# %%
df = df.drop(["veil-type"],axis=1)

# %%
df_div = pd.melt(df, 'class', var_name='Characteristics')
fig, ax = plt.subplots(figsize=(16,6))
p = sns.violinplot(ax = ax, x='Characteristics', y='value', hue='class', split = True, data=df_div, inner = 'quartile', palette = 'Set1')
df_no_class = df.drop(['class'],axis = 1)
p.set_xticklabels(rotation = 90, labels = list(df_no_class.columns));
#plt.savefig('violinplot.png', format='png', dpi=500, bbox_inches='tight')
# Out:
# C:\Users\varkumar\AppData\Local\Temp\ipykernel_29228\2553752155.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   p.set_xticklabels(rotation = 90, labels = list(df_no_class.columns));

# %% [markdown]
# Let's look at the correlation between the variables

# %%
# Empty list to store columns with categorical data
categorical = []
for col, value in df.items():
    if value.dtype == 'object':
        categorical.append(col)

# Store the numerical columns in a list numerical
numerical = df.columns.difference(categorical)

# %%
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
data = [
    go.Heatmap(
        z= df[numerical].astype(float).corr().values, # Generating the Pearson correlation
        x=df[numerical].columns.values,
        y=df[numerical].columns.values,
        colorscale='Viridis',
        reversescale = False,
#         text = True ,
        opacity = 1.0
        
    )
]


layout = go.Layout(
    title='Pearson Correlation of numerical features',
    xaxis = dict(ticks='', nticks=36),
    yaxis = dict(ticks='' ),
    width = 900, height = 700,
    
)


fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='labelled-heatmap')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#see the correlation
df[numerical].corr()
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# stalk-surface-above-ring -0.334593  -0.030417     0.089090  -0.060837
# stalk-surface-below-ring -0.298801  -0.032591     0.107965  -0.047710
# stalk-color-above-ring   -0.154003  -0.031659     0.066050   0.002364
# stalk-color-below-ring   -0.146730  -0.030390     0.068885   0.008057
# veil-color                0.145142   0.072560    -0.016603   0.036130
# ring-number              -0.214366  -0.106534    -0.026147  -0.005822
# ring-type                -0.411771  -0.025457    -0.106407   0.162513
# spore-print-color         0.171961  -0.073416     0.230364  -0.293523
# population                0.298686   0.063413     0.021555  -0.144770
# habitat                   0.217179  -0.042221     0.163887   0.033925
#
#                            bruises      odor  gill-attachment  gill-spacing  \
# class                    -0.501530 -0.093552         0.129200     -0.348387
# cap-shape                -0.035374 -0.021935         0.078865      0.013196
# cap-surface               0.070228  0.045233        -0.034180     -0.282306
# cap-color                -0.000764 -0.387121         0.041436      0.144259
# bruises                   1.000000 -0.061825         0.137359     -0.299473
# odor                     -0.061825  1.000000        -0.059590      0.063936
# gill-attachment           0.137359 -0.059590         1.000000      0.071489
# gill-spacing             -0.299473  0.063936         0.071489      1.000000
# gill-size                -0.369596  0.310495         0.108984     -0.108333
# gill-color                0.527120 -0.129213        -0.128567      0.100193
# stalk-shape               0.099364  0.459766         0.186485      0.080895
# stalk-root                0.244188 -0.205215         0.144063      0.350548
# stalk-surface-above-ring  0.460824  0.118617        -0.088916     -0.212359
# stalk-surface-below-ring  0.458983  0.061820        -0.116177     -0.213775
# stalk-color-above-ring    0.083538  0.174532         0.099299      0.274574
# stalk-color-below-ring    0.092874  0.169407         0.097160      0.253505
# veil-color                0.119770 -0.057747         0.897518      0.073363
# ring-number               0.056788  0.111905         0.093236      0.243014
# ring-type                 0.692973 -0.281387        -0.146689     -0.195897
# spore-print-color        -0.285008  0.469055        -0.029524      0.047323
# population                0.088137 -0.043623         0.165575     -0.529253
# habitat                  -0.075095 -0.026610        -0.030304     -0.154680
#
#                           gill-size  gill-color  ...  \
# class                      0.540024   -0.530566  ...
# cap-shape                  0.054050   -0.006039  ...
# cap-surface                0.208100   -0.161017  ...
# cap-color                 -0.169464    0.084659  ...
# bruises                   -0.369596    0.527120  ...
# odor                       0.310495   -0.129213  ...
# gill-attachment            0.108984   -0.128567  ...
# gill-spacing              -0.108333    0.100193  ...
# gill-size                  1.000000   -0.516736  ...
# gill-color                -0.516736    1.000000  ...
# stalk-shape                0.214576   -0.175699  ...
# stalk-root                -0.344345    0.315080  ...
# stalk-surface-above-ring   0.056310    0.224287  ...
# stalk-surface-below-ring   0.010894    0.257224  ...
# stalk-color-above-ring     0.296548   -0.058299  ...
# stalk-color-below-ring     0.278708   -0.074781  ...
# veil-color                 0.103809   -0.097583  ...
# ring-number               -0.171362    0.096054  ...
# ring-type                 -0.460872    0.629398  ...
# spore-print-color          0.622991   -0.416135  ...
# population                 0.147682   -0.034090  ...
# habitat                    0.161418   -0.202972  ...
#
#                           stalk-surface-above-ring  stalk-surface-below-ring  \
# class                                    -0.334593                 -0.298801
# cap-shape                                -0.030417                 -0.032591
# cap-surface                               0.089090                  0.107965
# cap-color                                -0.060837                 -0.047710
# bruises                                   0.460824                  0.458983
# odor                                      0.118617                  0.061820
# gill-attachment                          -0.088916                 -0.116177
# gill-spacing                             -0.212359                 -0.213775
# gill-size                                 0.056310                  0.010894
# gill-color                                0.224287                  0.257224
# stalk-shape                               0.015193                 -0.034399
# stalk-root                               -0.027065                  0.087454
# stalk-surface-above-ring                  1.000000                  0.437164
# stalk-surface-below-ring                  0.437164                  1.000000
# stalk-color-above-ring                    0.132708                  0.106933
# stalk-color-below-ring                    0.142835                  0.110656
# veil-color                               -0.090591                 -0.077284
# ring-number                               0.107904                  0.040006
# ring-type                                 0.390091                  0.394644
# spore-print-color                         0.100764                  0.130974
# population                                0.079604                  0.046797
# habitat                                  -0.058076                 -0.039628
#
#                           stalk-color-above-ring  stalk-color-below-ring  \
# class                                  -0.154003               -0.146730
# cap-shape                              -0.031659               -0.030390
# cap-surface                             0.066050                0.068885
# cap-color                               0.002364                0.008057
# bruises                                 0.083538                0.092874
# odor                                    0.174532                0.169407
# gill-attachment                         0.099299                0.097160
# gill-spacing                            0.274574                0.253505
# gill-size                               0.296548                0.278708
# gill-color                             -0.058299               -0.074781
# stalk-shape                             0.223439                0.235794
# stalk-root                              0.157140                0.159805
# stalk-surface-above-ring                0.132708                0.142835
# stalk-surface-below-ring                0.106933                0.110656
# stalk-color-above-ring                  1.000000                0.491510
# stalk-color-below-ring                  0.491510                1.000000
# veil-color                              0.067377                0.065567
# ring-number                             0.084917                0.087580
# ring-type                              -0.048878               -0.034284
# spore-print-color                       0.271533                0.254518
# population                             -0.240261               -0.242792
# habitat                                 0.042561                0.041594
#
#                           veil-color  ring-number  ring-type  \
# class                       0.145142    -0.214366  -0.411771
# cap-shape                   0.072560    -0.106534  -0.025457
# cap-surface                -0.016603    -0.026147  -0.106407
# cap-color                   0.036130    -0.005822   0.162513
# bruises                     0.119770     0.056788   0.692973
# odor                       -0.057747     0.111905  -0.281387
# gill-attachment             0.897518     0.093236  -0.146689
# gill-spacing                0.073363     0.243014  -0.195897
# gill-size                   0.103809    -0.171362  -0.460872
# gill-color                 -0.097583     0.096054   0.629398
# stalk-shape                 0.162604    -0.293221  -0.291444
# stalk-root                  0.156213    -0.247357   0.210155
# stalk-surface-above-ring   -0.090591     0.107904   0.390091
# stalk-surface-below-ring   -0.077284     0.040006   0.394644
# stalk-color-above-ring      0.067377     0.084917  -0.048878
# stalk-color-below-ring      0.065567     0.087580  -0.034284
# veil-color                  1.000000     0.036380  -0.143673
# ring-number                 0.036380     1.000000   0.058312
# ring-type                  -0.143673     0.058312   1.000000
# spore-print-color          -0.003600     0.338417  -0.487048
# population                  0.124924    -0.242020   0.211763
# habitat                    -0.040581     0.235835  -0.212080
#
#                           spore-print-color  population   habitat
# class                              0.171961    0.298686  0.217179
# cap-shape                         -0.073416    0.063413 -0.042221
# cap-surface                        0.230364    0.021555  0.163887
# cap-color                         -0.293523   -0.144770  0.033925
# bruises                           -0.285008    0.088137 -0.075095
# odor                               0.469055   -0.043623 -0.026610
# gill-attachment                   -0.029524    0.165575 -0.030304
# gill-spacing                       0.047323   -0.529253 -0.154680
# gill-size                          0.622991    0.147682  0.161418
# gill-color                        -0.416135   -0.034090 -0.202972
# stalk-shape                        0.258831    0.087383 -0.269216
# stalk-root                        -0.536996   -0.306747 -0.007668
# stalk-surface-above-ring           0.100764    0.079604 -0.058076
# stalk-surface-below-ring           0.130974    0.046797 -0.039628
# stalk-color-above-ring             0.271533   -0.240261  0.042561
# stalk-color-below-ring             0.254518   -0.242792  0.041594
# veil-color                        -0.003600    0.124924 -0.040581
# ring-number                        0.338417   -0.242020  0.235835
# ring-type                         -0.487048    0.211763 -0.212080
# spore-print-color                  1.000000   -0.126859  0.185954
# population                        -0.126859    1.000000 -0.174529
# habitat                            0.185954   -0.174529  1.000000
#
# [22 rows x 22 columns]

# %%
plt.figure(figsize=(14,12))
sns.heatmap(df.corr(),linewidths=.1,cmap="Purples", annot=True, annot_kws={"size": 7})
plt.yticks(rotation=0);

# %% [raw]
# Usually, the least correlating variable is the most important one for classification. In this case, “gill-color” is -0.53 so let's look at it closely:

# %%
df[['class', 'gill-color']].groupby(['gill-color'], as_index=False).mean().sort_values(by='class', ascending=False)
# Out:
#     gill-color     class
# 0            0  1.000000
# 8            8  1.000000
# 3            3  0.721311
# 2            2  0.670213
# 7            7  0.428954
# 11          11  0.255814
# 10          10  0.204659
# 4            4  0.156863
# 5            5  0.106870
# 9            9  0.097561
# 1            1  0.000000
# 6            6  0.000000

# %%
X = df.drop(['class'], axis=1)
y = df['class']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.1)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.score(X_test,y_test)
# Out:
# 1.0

# %%
features_list = X.columns.values
feature_importance = dt.feature_importances_
sorted_idx = np.argsort(feature_importance)
plt.figure(figsize=(8,7))
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center', color ="red")
plt.yticks(range(len(sorted_idx)), features_list[sorted_idx])
plt.xlabel('Importance')
plt.title('Feature importance')
plt.draw()
#plt.savefig("featureimp.png", format='png', dpi=500, bbox_inches='tight')
plt.show()

# %%
y_pred_dt = dt.predict(X_test)
cm = confusion_matrix(y_test, y_pred_dt)
cm
# Out:
# array([[433,   0],
#        [  0, 380]], dtype=int64)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
def find_best_model_using_gridsearchcv(X,y):
    algos = {
        'logistic_regression' : {
            'model': LogisticRegression(),
            'params': {
               'penalty' : ['l2'],
                'multi_class' : ['auto', 'ovr', 'multinomial'],
                'fit_intercept' : [True, False],
                 'n_jobs' : [1,2,3],
                'solver':['lbfgs'], 
                'max_iter':[400]
            }
        },
         'KNN': {
             'model': KNeighborsClassifier(),
             'params': {
                 'weights': ['uniform', 'distance'],
                 'algorithm': ['ball_tree', 'kd_tree']
             }
        },
        'SVC': {
             'model': SVC(),
             'params': {
                 'shrinking' : [True, False],
                 # 'splitter': ['best','random'],
                 'decision_function_shape' : ['ovo', 'ovr']
             }
        },
         'GaussianNB': {
             'model':GaussianNB(),
             'params': {
                
         }         
        }
    }
     
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, error_score='raise',return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(X,y)
# Out:
# C:\Users\varkumar\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# C:\Users\varkumar\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# C:\Users\varkumar\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# C:\Users\varkumar\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#                  model  best_score  \
# 0  logistic_regression    0.951015
# 1                  KNN    0.999262
# 2                  SVC    0.990646
# 3           GaussianNB    0.918523
#
#                                          best_params
# 0  {'fit_intercept': True, 'max_iter': 400, 'mult...
# 1  {'algorithm': 'ball_tree', 'weights': 'distance'}
# 2  {'decision_function_shape': 'ovo', 'shrinking'...
# 3                                                 {}

# %%
from lazypredict.Supervised import LazyClassifier
target_map = {1:'p', 0:'e'}
# Use the pandas apply method to numerically encode our attrition target variable
y1 = y.apply(lambda x: target_map[x])
X_train, X_test, y_train, y_test = train_test_split(X, y1, random_state=42, test_size=0.1)
clf = LazyClassifier(verbose=0,predictions=True)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:12<00:00,  5.12it/s]
# [LightGBM] [Info] Number of positive: 3536, number of negative: 3775
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000876 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 137
# [LightGBM] [Info] Number of data points in the train set: 7311, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.483655 -> initscore=-0.065404
# [LightGBM] [Info] Start training from score -0.065404
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:12<00:00,  2.35it/s]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 1.00               1.00    None      1.00
# KNeighborsClassifier               1.00               1.00    None      1.00
# SVC                                1.00               1.00    None      1.00
# RandomForestClassifier             1.00               1.00    None      1.00
# BaggingClassifier                  1.00               1.00    None      1.00
# LabelSpreading                     1.00               1.00    None      1.00
# LabelPropagation                   1.00               1.00    None      1.00
# LGBMClassifier                     1.00               1.00    None      1.00
# ExtraTreeClassifier                1.00               1.00    None      1.00
# DecisionTreeClassifier             1.00               1.00    None      1.00
# ExtraTreesClassifier               1.00               1.00    None      1.00
# QuadraticDiscriminantAnalysis      1.00               1.00    None      1.00
# SGDClassifier                      0.98               0.98    None      0.98
# LogisticRegression                 0.96               0.96    None      0.96
# LinearSVC                          0.95               0.95    None      0.95
# CalibratedClassifierCV             0.95               0.95    None      0.95
# LinearDiscriminantAnalysis         0.95               0.95    None      0.95
# RidgeClassifierCV                  0.95               0.95    None      0.95
# RidgeClassifier                    0.95               0.95    None      0.95
# GaussianNB                         0.93               0.93    None      0.93
# NuSVC                              0.92               0.92    None      0.92
# Perceptron                         0.92               0.91    None      0.92
# BernoulliNB                        0.89               0.88    None      0.89
# NearestCentroid                    0.87               0.87    None      0.87
# PassiveAggressiveClassifier        0.84               0.83    None      0.83
# DummyClassifier                    0.53               0.50    None      0.37
#
#                                Time Taken
# Model
# AdaBoostClassifier                   0.52
# KNeighborsClassifier                 0.96
# SVC                                  0.16
# RandomForestClassifier               0.28
# BaggingClassifier                    0.09
# LabelSpreading                       3.79
# LabelPropagation                     2.95
# LGBMClassifier                       0.22
# ExtraTreeClassifier                  0.02
# DecisionTreeClassifier               0.03
# ExtraTreesClassifier                 0.29
# QuadraticDiscriminantAnalysis        0.13
# SGDClassifier                        0.03
# LogisticRegression                   0.07
# LinearSVC                            0.21
# CalibratedClassifierCV               0.20
# LinearDiscriminantAnalysis           0.05
# RidgeClassifierCV                    0.04
# RidgeClassifier                      0.11
# GaussianNB                           0.03
# NuSVC                                1.98
# Perceptron                           0.02
# BernoulliNB                          0.03
# NearestCentroid                      0.03
# PassiveAggressiveClassifier          0.03
# DummyClassifier                      0.02

# %%
from sklearn.metrics import classification_report
for i in predictions.columns.tolist():
    print('\t\t',i,'\n')
    print(classification_report(y_test, predictions[i]),'\n')
# Out:
# 		 AdaBoostClassifier
#
#               precision    recall  f1-score   support
#
#            e       1.00      1.00      1.00       433
#            p       1.00      1.00      1.00       380
#
#     accuracy                           1.00       813
#    macro avg       1.00      1.00      1.00       813
# weighted avg       1.00      1.00      1.00       813
#
#
# 		 BaggingClassifier
#
#               precision    recall  f1-score   support
#
#            e       1.00      1.00      1.00       433
#            p       1.00      1.00      1.00       380
#
#     accuracy                           1.00       813
#    macro avg       1.00      1.00      1.00       813
# weighted avg       1.00      1.00      1.00       813
#
#
# 		 BernoulliNB
#
#               precision    recall  f1-score   support
#
#            e       0.85      0.96      0.90       433
#            p       0.94      0.81      0.87       380
#
#     accuracy                           0.89       813
#    macro avg       0.90      0.88      0.89       813
# weighted avg       0.89      0.89      0.89       813
#
#
# 		 CalibratedClassifierCV
#
#               precision    recall  f1-score   support
#
#            e       0.96      0.94      0.95       433
#            p       0.94      0.96      0.95       380
#
#     accuracy                           0.95       813
#    macro avg       0.95      0.95      0.95       813
# weighted avg       0.95      0.95      0.95       813
#
#
# 		 DecisionTreeClassifier
#
#               precision    recall  f1-score   support
#
#            e       1.00      1.00      1.00       433
#            p       1.00      1.00      1.00       380
#
#     accuracy                           1.00       813
#    macro avg       1.00      1.00      1.00       813
# weighted avg       1.00      1.00      1.00       813
#
#
# 		 DummyClassifier
#
#               precision    recall  f1-score   support
#
#            e       0.53      1.00      0.70       433
#            p       0.00      0.00      0.00       380
#
#     accuracy                           0.53       813
#    macro avg       0.27      0.50      0.35       813
# weighted avg       0.28      0.53      0.37       813
#
#
# 		 ExtraTreeClassifier
#
#               precision    recall  f1-score   support
#
#            e       1.00      1.00      1.00       433
#            p       1.00      1.00      1.00       380
#
#     accuracy                           1.00       813
#    macro avg       1.00      1.00      1.00       813
# weighted avg       1.00      1.00      1.00       813
#
#
# 		 ExtraTreesClassifier
#
#               precision    recall  f1-score   support
#
#            e       1.00      1.00      1.00       433
#            p       1.00      1.00      1.00       380
#
#     accuracy                           1.00       813
#    macro avg       1.00      1.00      1.00       813
# weighted avg       1.00      1.00      1.00       813
#
#
# 		 GaussianNB
#
#               precision    recall  f1-score   support
#
#            e       0.94      0.92      0.93       433
#            p       0.91      0.94      0.92       380
#
#     accuracy                           0.93       813
#    macro avg       0.93      0.93      0.93       813
# weighted avg       0.93      0.93      0.93       813
#
#
# 		 KNeighborsClassifier
#
#               precision    recall  f1-score   support
#
#            e       1.00      1.00      1.00       433
#            p       1.00      1.00      1.00       380
#
#     accuracy                           1.00       813
#    macro avg       1.00      1.00      1.00       813
# weighted avg       1.00      1.00      1.00       813
#
#
# 		 LabelPropagation
#
#               precision    recall  f1-score   support
#
#            e       1.00      1.00      1.00       433
#            p       1.00      1.00      1.00       380
#
#     accuracy                           1.00       813
#    macro avg       1.00      1.00      1.00       813
# weighted avg       1.00      1.00      1.00       813
#
#
# 		 LabelSpreading
#
#               precision    recall  f1-score   support
#
#            e       1.00      1.00      1.00       433
#            p       1.00      1.00      1.00       380
#
#     accuracy                           1.00       813
#    macro avg       1.00      1.00      1.00       813
# weighted avg       1.00      1.00      1.00       813
#
#
# 		 LinearDiscriminantAnalysis
#
#               precision    recall  f1-score   support
#
#            e       0.96      0.94      0.95       433
#            p       0.94      0.95      0.94       380
#
#     accuracy                           0.95       813
#    macro avg       0.95      0.95      0.95       813
# weighted avg       0.95      0.95      0.95       813
#
#
# 		 LinearSVC
#
#               precision    recall  f1-score   support
#
#            e       0.96      0.94      0.95       433
#            p       0.94      0.96      0.95       380
#
#     accuracy                           0.95       813
#    macro avg       0.95      0.95      0.95       813
# weighted avg       0.95      0.95      0.95       813
#
#
# 		 LogisticRegression
#
#               precision    recall  f1-score   support
#
#            e       0.97      0.95      0.96       433
#            p       0.94      0.96      0.95       380
#
#     accuracy                           0.96       813
#    macro avg       0.96      0.96      0.96       813
# weighted avg       0.96      0.96      0.96       813
#
#
# 		 NearestCentroid
#
#               precision    recall  f1-score   support
#
#            e       0.84      0.93      0.88       433
#            p       0.91      0.80      0.85       380
#
#     accuracy                           0.87       813
#    macro avg       0.88      0.87      0.87       813
# weighted avg       0.87      0.87      0.87       813
#
#
# 		 NuSVC
#
#               precision    recall  f1-score   support
#
#            e       0.88      0.99      0.93       433
#            p       0.98      0.84      0.91       380
#
#     accuracy                           0.92       813
#    macro avg       0.93      0.92      0.92       813
# weighted avg       0.93      0.92      0.92       813
#
#
# 		 PassiveAggressiveClassifier
#
#               precision    recall  f1-score   support
#
#            e       0.79      0.94      0.86       433
#            p       0.91      0.72      0.81       380
#
#     accuracy                           0.84       813
#    macro avg       0.85      0.83      0.83       813
# weighted avg       0.85      0.84      0.83       813
#
#
# 		 Perceptron
#
#               precision    recall  f1-score   support
#
#            e       0.87      0.98      0.93       433
#            p       0.98      0.84      0.90       380
#
#     accuracy                           0.92       813
#    macro avg       0.93      0.91      0.91       813
# weighted avg       0.92      0.92      0.92       813
#
#
# 		 QuadraticDiscriminantAnalysis
#
#               precision    recall  f1-score   support
#
#            e       1.00      1.00      1.00       433
#            p       1.00      0.99      1.00       380
#
#     accuracy                           1.00       813
#    macro avg       1.00      1.00      1.00       813
# weighted avg       1.00      1.00      1.00       813
#
#
# 		 RandomForestClassifier
#
#               precision    recall  f1-score   support
#
#            e       1.00      1.00      1.00       433
#            p       1.00      1.00      1.00       380
#
#     accuracy                           1.00       813
#    macro avg       1.00      1.00      1.00       813
# weighted avg       1.00      1.00      1.00       813
#
#
# 		 RidgeClassifier
#
#               precision    recall  f1-score   support
#
#            e       0.96      0.94      0.95       433
#            p       0.94      0.95      0.94       380
#
#     accuracy                           0.95       813
#    macro avg       0.95      0.95      0.95       813
# weighted avg       0.95      0.95      0.95       813
#
#
# 		 RidgeClassifierCV
#
#               precision    recall  f1-score   support
#
#            e       0.96      0.94      0.95       433
#            p       0.94      0.95      0.94       380
#
#     accuracy                           0.95       813
#    macro avg       0.95      0.95      0.95       813
# weighted avg       0.95      0.95      0.95       813
#
#
# 		 SGDClassifier
#
#               precision    recall  f1-score   support
#
#            e       0.99      0.98      0.98       433
#            p       0.98      0.98      0.98       380
#
#     accuracy                           0.98       813
#    macro avg       0.98      0.98      0.98       813
# weighted avg       0.98      0.98      0.98       813
#
#
# 		 SVC
#
#               precision    recall  f1-score   support
#
#            e       1.00      1.00      1.00       433
#            p       1.00      1.00      1.00       380
#
#     accuracy                           1.00       813
#    macro avg       1.00      1.00      1.00       813
# weighted avg       1.00      1.00      1.00       813
#
#
# 		 LGBMClassifier
#
#               precision    recall  f1-score   support
#
#            e       1.00      1.00      1.00       433
#            p       1.00      1.00      1.00       380
#
#     accuracy                           1.00       813
#    macro avg       1.00      1.00      1.00       813
# weighted avg       1.00      1.00      1.00       813

# %%
predictions.head()
# Out:
#   AdaBoostClassifier BaggingClassifier BernoulliNB CalibratedClassifierCV  \
# 0                  e                 e           e                      e
# 1                  p                 p           p                      p
# 2                  p                 p           p                      p
# 3                  e                 e           e                      e
# 4                  p                 p           p                      p
#
#   DecisionTreeClassifier DummyClassifier ExtraTreeClassifier  \
# 0                      e               e                   e
# 1                      p               e                   p
# 2                      p               e                   p
# 3                      e               e                   e
# 4                      p               e                   p
#
#   ExtraTreesClassifier GaussianNB KNeighborsClassifier  ... NuSVC  \
# 0                    e          e                    e  ...     e
# 1                    p          p                    p  ...     p
# 2                    p          p                    p  ...     p
# 3                    e          e                    e  ...     e
# 4                    p          p                    p  ...     p
#
#   PassiveAggressiveClassifier Perceptron QuadraticDiscriminantAnalysis  \
# 0                           e          e                             e
# 1                           e          p                             p
# 2                           p          p                             p
# 3                           e          e                             e
# 4                           e          p                             p
#
#   RandomForestClassifier RidgeClassifier RidgeClassifierCV SGDClassifier SVC  \
# 0                      e               e                 e             e   e
# 1                      p               p                 p             p   p
# 2                      p               p                 p             p   p
# 3                      e               e                 e             e   e
# 4                      p               p                 p             p   p
#
#   LGBMClassifier
# 0              e
# 1              p
# 2              p
# 3              e
# 4              p
#
# [5 rows x 26 columns]
